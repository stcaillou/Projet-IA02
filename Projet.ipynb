# %% [markdown]
# https://arxiv.org/pdf/1804.03209

# %%
import torchaudio
data = torchaudio.datasets.SPEECHCOMMANDS(download=True, root="./")

# %%
print("Nombre d'échantillon : ", data.__len__())
# Out:
# Nombre d'échantillon :  105829

# %% [markdown]
# Le dataset propose des ensemble pré-établi pour l'entraînement, la validation et le test.

# %%
data_train = torchaudio.datasets.SPEECHCOMMANDS(download=True, root="./", subset="training")
data_validation = torchaudio.datasets.SPEECHCOMMANDS(download=True, root="./", subset="validation")
data_testing = torchaudio.datasets.SPEECHCOMMANDS(download=True, root="./", subset="testing")

# %%
print("Nombre d'échantillon d'entrainement : ", data_train.__len__())
print("Nombre d'échantillon de validation : ", data_validation.__len__())
print("Nombre d'échantillon de test : ", data_testing.__len__())
# Out:
# Nombre d'échantillon d'entrainement :  84843
# Nombre d'échantillon de validation :  9981
# Nombre d'échantillon de test :  11005

# %%
import os
labels = os.listdir("./SpeechCommands/speech_commands_v0.02/")

labels.remove("README.md")
labels.remove("LICENSE")
labels.remove("testing_list.txt")
labels.remove("validation_list.txt")
labels.remove("_background_noise_")
labels.remove(".DS_Store")

print("Il y a  : ", len(labels), " labels")
print(labels)
# Out:
# Il y a  :  35  labels
# ['right', 'eight', 'tree', 'go', 'wow', 'happy', 'cat', 'dog', 'forward', 'bed', 'backward', 'zero', 'off', 'yes', 'learn', 'five', 'seven', 'sheila', 'left', 'nine', 'on', 'bird', 'no', 'follow', 'six', 'one', 'down', 'house', 'two', 'four', 'up', 'visual', 'stop', 'three', 'marvin']

# %%
import matplotlib.pyplot as plt

#Affichage de la distribution des ensembles proposé par le dataset
def distribution_dataset(dataset):
    count = [0 for i in range(len(labels))]

    for i in range(dataset.__len__()):
        count[labels.index(dataset.__getitem__(i)[2])] += 1
    
    plt.figure(figsize=(20,5))
    plt.xticks(rotation=90)
    plt.title("Distribution")
    plt.bar(labels, count)

# %%
distribution_dataset(data_train)

# %%
distribution_dataset(data_testing)

# %%
distribution_dataset(data_validation)

# %%
#Permet de récuperer un échantillon de chaque label

count = [0 for i in range(len(labels))]
sample = [[] for i in range(len(labels))]

for i in range(data_validation.__len__()):
    item = data_validation.__getitem__(i)
    index = labels.index(item[2])
    if count[index] == 0:
        sample[index] = item[0]
        count[index] = 1
    if sum(count) == 35:
        break

# %%
fig, axs = plt.subplots(7,5, figsize=(20,10))

for i in range(len(sample)):
    axs[i // 5, i%5].set_title(labels[i])
    axs[i // 5, i%5].plot(sample[i][0])

plt.tight_layout()
plt.show()

# %% [markdown]
# On réalise le même travail mais avec le spectrogramme

# %% [markdown]
# Pourquoi un spectrogramme ? Pourquoi un log ?

# %%
import torchaudio.transforms as T
import torch

fig, axs = plt.subplots(7,5, figsize=(20,20))
transform = T.MelSpectrogram(n_fft=1024, sample_rate=16000, n_mels=64, hop_length=512)

for i in range(len(sample)):
    spectrogram = transform(sample[i][0])
    axs[i // 5, i%5].imshow(spectrogram.numpy(), origin="lower", aspect="auto", interpolation="nearest")
    axs[i // 5, i%5].set_title(labels[i])

plt.tight_layout()
plt.show()

# %%
import torchaudio.transforms as T
import torch

fig, axs = plt.subplots(7,5, figsize=(20,20))
transform = T.MelSpectrogram(n_fft=1024, sample_rate=16000, n_mels=64, hop_length=512)

for i in range(len(sample)):
    spectrogram = transform(sample[i][0])
    log_mel = torch.log(spectrogram + 1e-10)
    axs[i // 5, i%5].imshow(log_mel.numpy(), origin="lower", aspect="auto", interpolation="nearest")
    axs[i // 5, i%5].set_title(labels[i])

plt.tight_layout()
plt.show()

# %%
irregulier_longueur_count = 0
irregulier_samplerate_count = 0

for i in data:
    if i[1] != 16000: irregulier_samplerate_count += 1
    if len(i[0][0]) != 16000: irregulier_longueur_count += 1

# %%
print(irregulier_samplerate_count)
# Out:
# 0

# %% [markdown]
# Les fichiers ont tous le même samplerate

# %%
print(irregulier_longueur_count)
# Out:
# 10435

# %% [markdown]
# La plus part des fichiers ne font pas la même taille

# %%
irregulier_grand_count = 0
irregulier_petit_count = 0

for i in data:
    if len(i[0][0])  < 16000: irregulier_petit_count += 1
    if len(i[0][0])  > 16000: irregulier_grand_count += 1

# %%
print(irregulier_grand_count)
# Out:
# 0

# %%
print(irregulier_petit_count)
# Out:
# 10435

# %% [markdown]
# Donc tout les segments sont plus petits que la longueur max. On va donc rajoute du silence a la fin des audio pour rendre les données uniforme.

# %%
from torch.utils.data import DataLoader

def pre_process_batch(batch):
    target_len = 16000
    new_batch = []
    
    for waveform, sample_rate, label_str, speaker_id, utterance_number in batch:

        #Ici on rajoute du bruit blanc en entree
        current_len = waveform.shape[1]
        if current_len < target_len:
            waveform = torch.nn.functional.pad(waveform, (0, target_len - current_len))
        
        #On reconstruit l'échantillon, avec l'indice du labels
        new_batch.append((waveform, labels.index(label_str)))

    waveforms = torch.stack([item[0] for item in new_batch])
    labels_tensor = torch.tensor([item[1] for item in new_batch])
    
    return waveforms, labels_tensor
 
train_loader = DataLoader(
    data_train, 
    batch_size=32, 
    shuffle=True,
    collate_fn=pre_process_batch 
)

val_loader = DataLoader(
    data_validation, 
    batch_size=32, 
    shuffle=True,
    collate_fn=pre_process_batch 
)

#for batch_idx, (waveforms, labels_batch) in enumerate(train_loader):
#    print(batch_idx, waveforms, labels_batch)
#    break

# %%
for batch_idx, (waveforms, labels_batch) in enumerate(train_loader):
   print(batch_idx, waveforms, labels_batch)
   break
# Out:
# 0 tensor([[[-2.2278e-03, -5.2185e-03, -7.3547e-03,  ...,  6.4697e-03,
#            5.5542e-03,  3.6316e-03]],
#
#         [[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -3.0518e-05,
#           -3.0518e-05, -3.0518e-05]],
#
#         [[ 0.0000e+00, -4.8828e-04, -3.0518e-04,  ..., -3.0518e-04,
#           -3.9673e-04, -6.1035e-04]],
#
#         ...,
#
#         [[-7.3242e-04, -5.7983e-04, -1.8311e-04,  ...,  1.3257e-01,
#            5.3192e-02,  2.0996e-02]],
#
#         [[ 2.7374e-02,  4.5715e-02,  4.0649e-02,  ..., -1.3733e-03,
#           -1.0986e-03,  3.3569e-04]],
#
#         [[ 0.0000e+00,  3.0518e-05, -3.0518e-05,  ..., -3.0518e-05,
#            3.0518e-05,  0.0000e+00]]]) tensor([32, 32, 10,  9,  4, 11, 14, 19, 22,  0, 22, 24, 24, 25, 12,  1, 11, 20,
#          3, 16, 25, 15, 12, 28, 17, 26, 12, 26, 28, 13, 29, 19])

# %%
class CNNModule(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.spec = T.MelSpectrogram(n_fft=1024, sample_rate=16000, n_mels=64, hop_length=512)

        self.cnn = torch.nn.Sequential(
            torch.nn.Conv2d(1, 32, kernel_size=3, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2),
            torch.nn.Conv2d(32, 64, kernel_size=3, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2) 
        )
        

        self.pool = torch.nn.AdaptiveAvgPool2d((4, 4)) 
        
        self.flatten = torch.nn.Flatten()
        
        self.dense = torch.nn.Linear(64 * 4 * 4, 35)

    def forward(self, x):
        x = self.spec(x)
        x = torch.log(x + 1e-10)

        #Permet de passer un seul élément pendant la phase de production
        if len(x.shape) <= 3:
            x = x.unsqueeze(0)

        x = self.cnn(x)

        x = self.pool(x)
        x = self.flatten(x)
        return self.dense(x)

# %%
import torch.optim as optim

device = "cpu"

model = CNNModule()
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
model.train() 

epochs = 3
best_loss = float('inf')
patience = 5

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    
    for batch_idx, (waveforms, labels_batch) in enumerate(train_loader):
        waveforms = waveforms.to(device)
        labels_batch = labels_batch.to(device)softmax(model(audio))
        
        optimizer.zero_grad()
        outputs = model(waveforms)
        loss = criterion(outputs, labels_batch)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        if batch_idx % 50 == 0:
            print(f"Epoch {epoch+1}/{epochs} | Batch {batch_idx}/{len(train_loader)} | Loss: {loss.item():.4f}")

    train_loss = running_loss / len(train_loader)
    
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for waveforms, labels_batch in val_loader:
            waveforms = waveforms.to(device)
            labels_batch = labels_batch.to(device)
            outputs = model(waveforms)
            loss = criterion(outputs, labels_batch)
            val_loss += loss.item()softmax(model(audio))
            _, predicted = torch.max(outputs, 1)
            total += labels_batch.size(0)
            correct += (predicted == labels_batch).sum().item()
    
    val_loss /= len(val_loader)
    val_acc = correct / total
    
    print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
    
    if val_loss < best_loss:
        best_loss = val_loss
        trigger_times = 0
        torch.save(model.state_dict(), 'best_model.pth')
        print(f"Nouveau meilleur modèle sauvegardé (Validation Loss: {best_loss:.4f})")
    else:
        trigger_times += 1
        print(f"Pas d'amélioration. Compteur Early Stopping: {trigger_times}/{patience}")
        if trigger_times >= patience:
            print(f"Early Stopping déclenché ! Arrêt à l'époque {epoch+1}")
            break
# Out:
# Epoch 1/3 | Batch 0/2652 | Loss: 3.7270
# Epoch 1/3 | Batch 50/2652 | Loss: 3.3062
# Epoch 1/3 | Batch 100/2652 | Loss: 3.1581
# Epoch 1/3 | Batch 150/2652 | Loss: 2.5916
# Epoch 1/3 | Batch 200/2652 | Loss: 2.7063
# Epoch 1/3 | Batch 250/2652 | Loss: 2.4421
# Epoch 1/3 | Batch 300/2652 | Loss: 3.0498
# Epoch 1/3 | Batch 350/2652 | Loss: 2.9911
# Epoch 1/3 | Batch 400/2652 | Loss: 1.8601
# Epoch 1/3 | Batch 450/2652 | Loss: 1.9769
# Epoch 1/3 | Batch 500/2652 | Loss: 1.7280
# Epoch 1/3 | Batch 550/2652 | Loss: 1.8899
# Epoch 1/3 | Batch 600/2652 | Loss: 1.7761
# Epoch 1/3 | Batch 650/2652 | Loss: 2.2294
# Epoch 1/3 | Batch 700/2652 | Loss: 1.8168
# Epoch 1/3 | Batch 750/2652 | Loss: 1.7752
# Epoch 1/3 | Batch 800/2652 | Loss: 1.6380
# Epoch 1/3 | Batch 850/2652 | Loss: 1.5042
# Epoch 1/3 | Batch 900/2652 | Loss: 1.8546
# Epoch 1/3 | Batch 950/2652 | Loss: 1.6013
# Epoch 1/3 | Batch 1000/2652 | Loss: 1.3508
# Epoch 1/3 | Batch 1050/2652 | Loss: 1.1647
# Epoch 1/3 | Batch 1100/2652 | Loss: 1.7695
# Epoch 1/3 | Batch 1150/2652 | Loss: 1.6359
# Epoch 1/3 | Batch 1200/2652 | Loss: 1.2204
# Epoch 1/3 | Batch 1250/2652 | Loss: 1.3955
# Epoch 1/3 | Batch 1300/2652 | Loss: 0.9724
# Epoch 1/3 | Batch 1350/2652 | Loss: 1.3547
# Epoch 1/3 | Batch 1400/2652 | Loss: 1.3058
# Epoch 1/3 | Batch 1450/2652 | Loss: 1.6130
# Epoch 1/3 | Batch 1500/2652 | Loss: 1.1626
# Epoch 1/3 | Batch 1550/2652 | Loss: 0.6954
# Epoch 1/3 | Batch 1600/2652 | Loss: 1.3205
# Epoch 1/3 | Batch 1650/2652 | Loss: 1.1997
# Epoch 1/3 | Batch 1700/2652 | Loss: 1.1232
# Epoch 1/3 | Batch 1750/2652 | Loss: 1.4072
# Epoch 1/3 | Batch 1800/2652 | Loss: 1.4766
# Epoch 1/3 | Batch 1850/2652 | Loss: 1.2886
# Epoch 1/3 | Batch 1900/2652 | Loss: 0.7139
# Epoch 1/3 | Batch 1950/2652 | Loss: 1.3622
# Epoch 1/3 | Batch 2000/2652 | Loss: 1.6368
# Epoch 1/3 | Batch 2050/2652 | Loss: 0.9891
# Epoch 1/3 | Batch 2100/2652 | Loss: 1.1363
# Epoch 1/3 | Batch 2150/2652 | Loss: 1.3380
# Epoch 1/3 | Batch 2200/2652 | Loss: 0.8950
# Epoch 1/3 | Batch 2250/2652 | Loss: 1.2697
# Epoch 1/3 | Batch 2300/2652 | Loss: 0.6773
# Epoch 1/3 | Batch 2350/2652 | Loss: 0.8871
# Epoch 1/3 | Batch 2400/2652 | Loss: 0.7985
# Epoch 1/3 | Batch 2450/2652 | Loss: 0.6503
# Epoch 1/3 | Batch 2500/2652 | Loss: 0.6123
# Epoch 1/3 | Batch 2550/2652 | Loss: 1.1398
# Epoch 1/3 | Batch 2600/2652 | Loss: 0.6034
# Epoch 1/3 | Batch 2650/2652 | Loss: 1.7286
# Epoch 1/3 | Train Loss: 1.5635 | Val Loss: 0.9884 | Val Acc: 0.7197
# Nouveau meilleur modèle sauvegardé (Validation Loss: 0.9884)
# Epoch 2/3 | Batch 0/2652 | Loss: 0.9042
# Epoch 2/3 | Batch 50/2652 | Loss: 1.0587
# Epoch 2/3 | Batch 100/2652 | Loss: 0.8892
# Epoch 2/3 | Batch 150/2652 | Loss: 0.8257
# Epoch 2/3 | Batch 200/2652 | Loss: 0.9279
# Epoch 2/3 | Batch 250/2652 | Loss: 0.8915
# Epoch 2/3 | Batch 300/2652 | Loss: 0.5865
# Epoch 2/3 | Batch 350/2652 | Loss: 0.8927
# Epoch 2/3 | Batch 400/2652 | Loss: 0.8397
# Epoch 2/3 | Batch 450/2652 | Loss: 1.1279
# Epoch 2/3 | Batch 500/2652 | Loss: 1.1233
# Epoch 2/3 | Batch 550/2652 | Loss: 0.7837
# Epoch 2/3 | Batch 600/2652 | Loss: 0.8524
# Epoch 2/3 | Batch 650/2652 | Loss: 0.7763
# Epoch 2/3 | Batch 700/2652 | Loss: 0.7627
# Epoch 2/3 | Batch 750/2652 | Loss: 0.9278
# Epoch 2/3 | Batch 800/2652 | Loss: 0.8255
# Epoch 2/3 | Batch 850/2652 | Loss: 0.7845
# Epoch 2/3 | Batch 900/2652 | Loss: 1.0880
# Epoch 2/3 | Batch 950/2652 | Loss: 0.8192
# Epoch 2/3 | Batch 1000/2652 | Loss: 0.8737
# Epoch 2/3 | Batch 1050/2652 | Loss: 0.7456
# Epoch 2/3 | Batch 1100/2652 | Loss: 0.7445
# Epoch 2/3 | Batch 1150/2652 | Loss: 0.9534
# Epoch 2/3 | Batch 1200/2652 | Loss: 0.7903
# Epoch 2/3 | Batch 1250/2652 | Loss: 1.0174
# Epoch 2/3 | Batch 1300/2652 | Loss: 0.5328
# Epoch 2/3 | Batch 1350/2652 | Loss: 0.9444
# Epoch 2/3 | Batch 1400/2652 | Loss: 1.0812
# Epoch 2/3 | Batch 1450/2652 | Loss: 1.2607
# Epoch 2/3 | Batch 1500/2652 | Loss: 0.9883
# Epoch 2/3 | Batch 1550/2652 | Loss: 0.7632
# Epoch 2/3 | Batch 1600/2652 | Loss: 0.5762
# Epoch 2/3 | Batch 1650/2652 | Loss: 1.0052
# Epoch 2/3 | Batch 1700/2652 | Loss: 0.8599
# Epoch 2/3 | Batch 1750/2652 | Loss: 1.0341
# Epoch 2/3 | Batch 1800/2652 | Loss: 0.8422
# Epoch 2/3 | Batch 1850/2652 | Loss: 1.2903
# Epoch 2/3 | Batch 1900/2652 | Loss: 0.9152
# Epoch 2/3 | Batch 1950/2652 | Loss: 0.8870
# Epoch 2/3 | Batch 2000/2652 | Loss: 0.9801
# Epoch 2/3 | Batch 2050/2652 | Loss: 0.7919
# Epoch 2/3 | Batch 2100/2652 | Loss: 0.6931
# Epoch 2/3 | Batch 2150/2652 | Loss: 0.6776
# Epoch 2/3 | Batch 2200/2652 | Loss: 0.7186
# Epoch 2/3 | Batch 2250/2652 | Loss: 0.9097
# Epoch 2/3 | Batch 2300/2652 | Loss: 0.5422
# Epoch 2/3 | Batch 2350/2652 | Loss: 0.6991
# Epoch 2/3 | Batch 2400/2652 | Loss: 0.6539
# Epoch 2/3 | Batch 2450/2652 | Loss: 1.0419
# Epoch 2/3 | Batch 2500/2652 | Loss: 0.4737
# Epoch 2/3 | Batch 2550/2652 | Loss: 0.4815
# Epoch 2/3 | Batch 2600/2652 | Loss: 0.6423
# Epoch 2/3 | Batch 2650/2652 | Loss: 0.8505
# Epoch 2/3 | Train Loss: 0.8356 | Val Loss: 0.7435 | Val Acc: 0.7972
# Nouveau meilleur modèle sauvegardé (Validation Loss: 0.7435)
# Epoch 3/3 | Batch 0/2652 | Loss: 0.5468
# Epoch 3/3 | Batch 50/2652 | Loss: 0.6470
# Epoch 3/3 | Batch 100/2652 | Loss: 0.4176
# Epoch 3/3 | Batch 150/2652 | Loss: 0.4507
# Epoch 3/3 | Batch 200/2652 | Loss: 0.4888
# Epoch 3/3 | Batch 250/2652 | Loss: 0.3689
# Epoch 3/3 | Batch 300/2652 | Loss: 1.1081
# Epoch 3/3 | Batch 350/2652 | Loss: 0.8213
# Epoch 3/3 | Batch 400/2652 | Loss: 0.9592
# Epoch 3/3 | Batch 450/2652 | Loss: 1.2883
# Epoch 3/3 | Batch 500/2652 | Loss: 0.4892
# Epoch 3/3 | Batch 550/2652 | Loss: 0.3675
# Epoch 3/3 | Batch 600/2652 | Loss: 0.7922
# Epoch 3/3 | Batch 650/2652 | Loss: 1.5305
# Epoch 3/3 | Batch 700/2652 | Loss: 0.5958
# Epoch 3/3 | Batch 750/2652 | Loss: 0.7486
# Epoch 3/3 | Batch 800/2652 | Loss: 0.6358
# Epoch 3/3 | Batch 850/2652 | Loss: 0.3244
# Epoch 3/3 | Batch 900/2652 | Loss: 0.7086
# Epoch 3/3 | Batch 950/2652 | Loss: 0.5008
# Epoch 3/3 | Batch 1000/2652 | Loss: 0.7223
# Epoch 3/3 | Batch 1050/2652 | Loss: 0.7726
# Epoch 3/3 | Batch 1100/2652 | Loss: 0.2841
# Epoch 3/3 | Batch 1150/2652 | Loss: 0.9335
# Epoch 3/3 | Batch 1200/2652 | Loss: 0.6403
# Epoch 3/3 | Batch 1250/2652 | Loss: 1.0550
# Epoch 3/3 | Batch 1300/2652 | Loss: 0.7687
# Epoch 3/3 | Batch 1350/2652 | Loss: 0.2983
# Epoch 3/3 | Batch 1400/2652 | Loss: 0.7173
# Epoch 3/3 | Batch 1450/2652 | Loss: 0.8427
# Epoch 3/3 | Batch 1500/2652 | Loss: 0.3922
# Epoch 3/3 | Batch 1550/2652 | Loss: 0.3044
# Epoch 3/3 | Batch 1600/2652 | Loss: 0.7369
# Epoch 3/3 | Batch 1650/2652 | Loss: 0.6756
# Epoch 3/3 | Batch 1700/2652 | Loss: 0.7979
# Epoch 3/3 | Batch 1750/2652 | Loss: 0.5544
# Epoch 3/3 | Batch 1800/2652 | Loss: 0.3944
# Epoch 3/3 | Batch 1850/2652 | Loss: 0.7495
# Epoch 3/3 | Batch 1900/2652 | Loss: 0.5597
# Epoch 3/3 | Batch 1950/2652 | Loss: 0.6947
# Epoch 3/3 | Batch 2000/2652 | Loss: 0.6257
# Epoch 3/3 | Batch 2050/2652 | Loss: 0.5444
# Epoch 3/3 | Batch 2100/2652 | Loss: 0.7058
# Epoch 3/3 | Batch 2150/2652 | Loss: 0.7897
# Epoch 3/3 | Batch 2200/2652 | Loss: 0.5588
# Epoch 3/3 | Batch 2250/2652 | Loss: 0.8342
# Epoch 3/3 | Batch 2300/2652 | Loss: 0.3529
# Epoch 3/3 | Batch 2350/2652 | Loss: 0.8054
# Epoch 3/3 | Batch 2400/2652 | Loss: 0.7279
# Epoch 3/3 | Batch 2450/2652 | Loss: 0.4615
# Epoch 3/3 | Batch 2500/2652 | Loss: 0.9141
# Epoch 3/3 | Batch 2550/2652 | Loss: 0.7490
# Epoch 3/3 | Batch 2600/2652 | Loss: 0.6714
# Epoch 3/3 | Batch 2650/2652 | Loss: 0.2831
# Epoch 3/3 | Train Loss: 0.6874 | Val Loss: 0.6739 | Val Acc: 0.8107
# Nouveau meilleur modèle sauvegardé (Validation Loss: 0.6739)

# %%
###Pour évaluer les performances

def eval_performance(model_to_eval, dataset_eval):
    model_to_eval.eval()
    correct = 0
    softmax = torch.nn.Softmax(dim=1)

    with torch.no_grad():
        for i in range(0,len(dataset_eval)):
            elem = dataset_eval.__getitem__(i)

            output = model_to_eval(elem[0])
            res = softmax(output)

            if res.argmax(dim=1).item() == labels.index(elem[2]): correct = correct + 1

    print("Accuracry : ", correct / len(dataset_eval) * 100, "%")softmax(model(audio))
    return correct / len(dataset_eval)

eval_performance(model, data_validation)
# Out:
# Accuracry :  80.3727081454764 %
# 0.803727081454764

# %%
# %pip install sounddevice
# %pip install scipy
# Out:
# Requirement already satisfied: sounddevice in ./.venv/lib/python3.11/site-packages (0.5.5)
# Requirement already satisfied: cffi in ./.venv/lib/python3.11/site-packages (from sounddevice) (2.0.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.11/site-packages (from cffi->sounddevice) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting scipy
#   Downloading scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in ./.venv/lib/python3.11/site-packages (from scipy) (2.4.4)
# Downloading scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 87.2 MB/s  0:00:006m0:00:0100:01
# Installing collected packages: scipy
# Successfully installed scipy-1.17.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import sounddevice as sd
from scipy.io.wavfile import write

"""
print(sd.query_devices())
device_info = sd.query_devices(10)
print(device_info)
"""

model = CNNModule()

model.load_state_dict(torch.load("./best_model.pth", weights_only=True))


device_index = 10

sd.default.device = device_index

duration = 1 
fs = int(sd.query_devices(device_index)["default_samplerate"])
filename = "capture.wav"

print("Enregistrement en cours...")
audio = sd.rec(int(duration * fs), samplerate=fs, channels=1)
sd.wait() 
print("Enregistrement terminé.")

audio = torch.from_numpy(audio.T).float()

if fs != 16000 : 
    resampler = torchaudio.transforms.Resample(orig_freq=fs, new_freq=16000)
    audio = resampler(audio)


model.eval()

softmax_eval_live = torch.nn.Softmax(dim=1)

plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
plt.title("Distribution")
plt.bar(labels,softmax_eval_live(model(audio))[0].detach().numpy())

write(filename, 16000, audio.T.numpy())
print(f"Audio sauvegardé dans {filename}")
# Out:
# Enregistrement en cours...
# Enregistrement terminé.
# Audio sauvegardé dans capture.wav
